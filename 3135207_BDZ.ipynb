# %% [markdown]
# # University of Stirling

# %% [markdown]
# # Assignment Autumn 2023
#     The solution to my assignment

# %% [markdown]
# # Using python to read a file
#     Using pandas library to enable our program read through files

# %%
# importing libraries from python 
import pandas as pd
import matplotlib.pyplot as plt

# %%
# enabling IPython to display matplotlib graphs 
# %matplotlib inline

# %%
# Exploring the csv files using pandas library to read through it

# %%
# This code enables our interpreter to read through the users.csv file
user = pd.read_csv('users.csv.csv')

# %%
# Displaying the output(data) of the user.csv file
user
# Out:
#       Username         DOB          State
# 0     bkpn1412  31.07.1983         Oregon
# 1     gqjs4414  27.07.1998  Massachusetts
# 2     eehe1434  08.08.1950          Idaho
# 3     hkxj1334  03.08.1969        Florida
# 4     jjbd1412  26.07.2001        Georgia
# ...        ...         ...            ...
# 4995  mfnn1212  27.07.1997       Delaware
# 4996  ejnb3414  01.08.1976      Minnesota
# 4997  pdzw1433  28.07.1994           Ohio
# 4998  npha1342  07.08.1953        Montana
# 4999  yuoc2324  02.08.1975   South Dakota
#
# [5000 rows x 3 columns]

# %%
# Inspecting the data in the file

# %%
# Using the head() to display some number of the first rows 
user.head(10 + 1)
# Out:
#     Username         DOB          State
# 0   bkpn1412  31.07.1983         Oregon
# 1   gqjs4414  27.07.1998  Massachusetts
# 2   eehe1434  08.08.1950          Idaho
# 3   hkxj1334  03.08.1969        Florida
# 4   jjbd1412  26.07.2001        Georgia
# 5   rriz2231  08.08.1951        Montana
# 6   dvmv4241  02.08.1975   Pennsylvania
# 7   ibtk1124  31.07.1983    Connecticut
# 8   ryqz4413  28.07.1992       Arkansas
# 9   ezng1232  03.08.1968       Nebraska
# 10  asfi3222  01.08.1977     California

# %%
# Checking if there is any missing data in the file provided and showing the total number of missing items in each field(column)
user.isnull().sum()
# Out:
# Username    0
# DOB         0
# State       0
# dtype: int64

# %%
# displaying our user data in a bar chart format for better visualization

# %%
# visualizing the data with the aid of bar plot
user_graph = user['State'].value_counts().plot(kind='bar', figsize=(30, 10), fontsize=15)
user_graph.set_xlabel('State', fontsize=25)
user_graph.set_ylabel('No. Of Occurance', fontsize=25)
user_graph.set_title('User graph', fontsize=25)
# Out:
# Text(0.5, 1.0, 'User graph')

# %%
# Reading through the products.csv file

# %%
# This code enables our interpreter to read through the products.csv file
products = pd.read_csv('products.csv.csv')

# %%
# Displaying the output(data) of the products.csv file
products
# Out:
#                                Uniq_id           SKU  \
# 0     b6c0b6bea69c722939585baeac73c13d  pp5006380337
# 1     93e5272c51d8cce02597e3ce67b7ad0a  pp5006380337
# 2     013e320f2f2ec0cf5b3ff5418d688528  pp5006380337
# 3     505e6633d81f2cb7400c0cfa0394c427  pp5006380337
# 4     d969a8542122e1331e304b09f81a83f6  pp5006380337
# ...                                ...           ...
# 7977  16e3ca6b6a2d3f5da9a81df6cfe7e27a  pp5002691549
# 7978  209bec04d9f194616358a77d7b41b314  pp5002691549
# 7979  7a8a7cba7b69b4c46ceac1d9666d84f0  pp5002691549
# 7980  9887bb20c12be3c09d094e97ac8d22be  pp5005921226
# 7981  2cc49292b44cc12fe22206440d3e7472  pp5005921226
#
#                                              Name  \
# 0     Alfred Dunner® Essential Pull On Capri Pant
# 1     Alfred Dunner® Essential Pull On Capri Pant
# 2     Alfred Dunner® Essential Pull On Capri Pant
# 3     Alfred Dunner® Essential Pull On Capri Pant
# 4     Alfred Dunner® Essential Pull On Capri Pant
# ...

# %%
# Inspecting the data in the file

# %%
# Using the head() to display some number of the first rows 
products.head(10 + 1)
# Out:
#                              Uniq_id           SKU  \
# 0   b6c0b6bea69c722939585baeac73c13d  pp5006380337
# 1   93e5272c51d8cce02597e3ce67b7ad0a  pp5006380337
# 2   013e320f2f2ec0cf5b3ff5418d688528  pp5006380337
# 3   505e6633d81f2cb7400c0cfa0394c427  pp5006380337
# 4   d969a8542122e1331e304b09f81a83f6  pp5006380337
# 5   cf73bb2bd93bbd6e1bdf48d399992270  pp5006380337
# 6   8ffd0ef4fcaf1a82fb514aba5d20e05b  pp5006790247
# 7   4d9337e3c8f974d3c420cdc5c58b3fc3  pp5007090172
# 8   44f8f8f108c6856acf9630dd1d78516d  pp5007080134
# 9   8d1d057f5f808c10ce243c222ab0ef6e  pp5007080134
# 10  f3e02c48f16b56e8c1f126c8fe762812  pp5007080134
#
#                                                  Name  \
# 0         Alfred Dunner® Essential Pull On Capri Pant
# 1         Alfred Dunner® Essential Pull On Capri Pant
# 2         Alfred Dunner® Essential Pull On Capri Pant
# 3         Alfred Dunner® Essential Pull On Capri Pant
# 4         Alfred Dunner® Essential Pull On Capri Pant
# ...

# %%
# Checking if there is any missing data in the file provided and showing the total number of missing items in each field(column)
products.isnull().sum()
# Out:
# Uniq_id           0
# SKU              67
# Name              0
# Description     543
# Price          2166
# Av_Score          0
# dtype: int64

# %%
# displaying our user data in a bar chart format for better visualization

# %%
# visualizing the data with the aid of bar plot
product_graph = products['Av_Score'].value_counts().plot(kind='bar', figsize=(30, 10), fontsize=12)
product_graph.set_xlabel('Av_Score', fontsize=30)
product_graph.set_ylabel('No. Of Occurance',fontsize=30)
product_graph.set_title('Product graph', fontsize=25)
# Out:
# Text(0.5, 1.0, 'Product graph')

# %%
# Reading through the reviews.csv file

# %%
# This code enables our interpreter to read through the reviews.csv file
reviews = pd.read_csv('reviews.csv.csv')

# %%
# Displaying the output(data) of the reviews.csv file
reviews
# Out:
#                                 Uniq_id  Username  Score  \
# 0      b6c0b6bea69c722939585baeac73c13d  fsdv4141      2
# 1      b6c0b6bea69c722939585baeac73c13d  krpz1113      1
# 2      b6c0b6bea69c722939585baeac73c13d  mbmg3241      2
# 3      b6c0b6bea69c722939585baeac73c13d  zeqg1222      0
# 4      b6c0b6bea69c722939585baeac73c13d  nvfn3212      3
# ...                                 ...       ...    ...
# 39058  2cc49292b44cc12fe22206440d3e7472  whxp1433      2
# 39059  2cc49292b44cc12fe22206440d3e7472  kfqi4333      1
# 39060  2cc49292b44cc12fe22206440d3e7472  bynj4221      0
# 39061  2cc49292b44cc12fe22206440d3e7472  eawq2222      1
# 39062  2cc49292b44cc12fe22206440d3e7472  mcxs2141      1
#
#                                                   Review
# 0      You never have to worry about the fit...Alfred...
# 1      Good quality fabric. Perfect fit. Washed very ...
# 2      I do not normally wear pants or capris that ha...
# ...

# %%
# Using the head() to display some number of the first rows 
reviews.head(10 + 1)
# Out:
#                              Uniq_id  Username  Score  \
# 0   b6c0b6bea69c722939585baeac73c13d  fsdv4141      2
# 1   b6c0b6bea69c722939585baeac73c13d  krpz1113      1
# 2   b6c0b6bea69c722939585baeac73c13d  mbmg3241      2
# 3   b6c0b6bea69c722939585baeac73c13d  zeqg1222      0
# 4   b6c0b6bea69c722939585baeac73c13d  nvfn3212      3
# 5   b6c0b6bea69c722939585baeac73c13d  aajh3423      2
# 6   b6c0b6bea69c722939585baeac73c13d  usvp2142      1
# 7   b6c0b6bea69c722939585baeac73c13d  yemw3321      1
# 8   93e5272c51d8cce02597e3ce67b7ad0a  tpcu2211      3
# 9   93e5272c51d8cce02597e3ce67b7ad0a  vutl2421      2
# 10  93e5272c51d8cce02597e3ce67b7ad0a  ixlo1324      0
#
#                                                Review
# 0   You never have to worry about the fit...Alfred...
# 1   Good quality fabric. Perfect fit. Washed very ...
# 2   I do not normally wear pants or capris that ha...
# 3   I love these capris! They fit true to size and...
# ...

# %%
# Checking if there is any missing data in the file provided and showing the total number of missing items in each field(column)
reviews.isnull().sum()
# Out:
# Uniq_id     0
# Username    0
# Score       0
# Review      0
# dtype: int64

# %%
# displaying our user data in a bar chart format for better visualization

# %%
# visualizing the data with the aid of bar plot
review_graph = reviews['Score'].value_counts().plot(kind='bar', figsize=(7, 5), fontsize=16)
review_graph.set_xlabel('Score', fontsize=20)
review_graph.set_ylabel('No. Of Occurance',fontsize=20)
review_graph.set_title('Review graph', fontsize=25)
# Out:
# Text(0.5, 1.0, 'Review graph')

# %%
# Creating variables and data structure from the three data's we have from our csv files

# %%
# Creating a new data from the csv file provided
new_data = pd.concat([user, products, reviews])

# %%
# Output the new data
new_data
# Out:
#        Username         DOB          State                           Uniq_id  \
# 0      bkpn1412  31.07.1983         Oregon                               NaN
# 1      gqjs4414  27.07.1998  Massachusetts                               NaN
# 2      eehe1434  08.08.1950          Idaho                               NaN
# 3      hkxj1334  03.08.1969        Florida                               NaN
# 4      jjbd1412  26.07.2001        Georgia                               NaN
# ...         ...         ...            ...                               ...
# 39058  whxp1433         NaN            NaN  2cc49292b44cc12fe22206440d3e7472
# 39059  kfqi4333         NaN            NaN  2cc49292b44cc12fe22206440d3e7472
# 39060  bynj4221         NaN            NaN  2cc49292b44cc12fe22206440d3e7472
# 39061  eawq2222         NaN            NaN  2cc49292b44cc12fe22206440d3e7472
# 39062  mcxs2141         NaN            NaN  2cc49292b44cc12fe22206440d3e7472
#
# ...

# %%
# Minimizing the length of our rows by deleting some rows
new_data.drop(new_data.index[0:52005], inplace=True)

# %%
# To check the no. of rows and column in our data frame
new_data.shape
# Out:
# (40, 11)

# %%
new_data
# Out:
#        Username  DOB State                           Uniq_id  SKU Name  \
# 39023  cced4433  NaN   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN  NaN
# 39024  ylwh3213  NaN   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN  NaN
# 39025  vcqh3224  NaN   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN  NaN
# 39026  tmse4424  NaN   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN  NaN
# 39027  awzt1433  NaN   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN  NaN
# 39028  fcnf1412  NaN   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN  NaN
# 39029  owuk2231  NaN   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN  NaN
# 39030  ipkl1143  NaN   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN  NaN
# 39031  rtbj4421  NaN   NaN  209bec04d9f194616358a77d7b41b314  NaN  NaN
# 39032  rnec1332  NaN   NaN  209bec04d9f194616358a77d7b41b314  NaN  NaN
# 39033  rgvh4144  NaN   NaN  209bec04d9f194616358a77d7b41b314  NaN  NaN
# 39034  crwq1342  NaN   NaN  209bec04d9f194616358a77d7b41b314  NaN  NaN
# ...

# %%
# changing and renaming the values of the index in the data
new_data.rename(index={39023:1, 39024:2, 39025:3, 39026:4, 39027:5, 39028:6, 39029:7, 39030:8, 39031:9, 39032:10, 39033:11, 39034:12, 39035:13, 39036:14, 39037:15, 39038:16, 39039:17, 39040:18, 39041:19, 39042:20, 39043:21, 39044:22, 39045:23, 39046:24, 39047:25, 39048:26, 39049:27, 39050:28, 39051:29, 39052:30, 39053:31, 39054:32, 39055:33, 39056:34, 39057:35, 39058:36, 39059:37, 39060:38, 39061:39, 39062:40}, inplace=True)

# %%
 new_data
# Out:
#     Username  DOB State                           Uniq_id  SKU Name  \
# 1   cced4433  NaN   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN  NaN
# 2   ylwh3213  NaN   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN  NaN
# 3   vcqh3224  NaN   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN  NaN
# 4   tmse4424  NaN   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN  NaN
# 5   awzt1433  NaN   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN  NaN
# 6   fcnf1412  NaN   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN  NaN
# 7   owuk2231  NaN   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN  NaN
# 8   ipkl1143  NaN   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN  NaN
# 9   rtbj4421  NaN   NaN  209bec04d9f194616358a77d7b41b314  NaN  NaN
# 10  rnec1332  NaN   NaN  209bec04d9f194616358a77d7b41b314  NaN  NaN
# 11  rgvh4144  NaN   NaN  209bec04d9f194616358a77d7b41b314  NaN  NaN
# 12  crwq1342  NaN   NaN  209bec04d9f194616358a77d7b41b314  NaN  NaN
# 13  bics4343  NaN   NaN  209bec04d9f194616358a77d7b41b314  NaN  NaN
# ...

# %%
# replacing all the empty DOB in our dataframe using iat[] method

# %%
# replacing the first row
new_data.iat[0,1] = '15th June 2000'

# replacing the second row
new_data.iat[1,1] = '15th June 1960'

# replacing the third row
new_data.iat[2,1] = '15th July 1910'

# replacing the fourth row
new_data.iat[3,1] = '5th August 1900'

# replacing the fifth row
new_data.iat[4,1] = '1st May 1962'

# replacing the sixth row
new_data.iat[5,1] = '2nd June 1980'

# replacing the seventh row
new_data.iat[6,1] = '3rd June 2001'

# replacing the eight row
new_data.iat[7,1] = '4th Feb. 2000'

# replacing the ninth row
new_data.iat[8,1] = '1st Sep. 1828'

# replacing the tenth row
new_data.iat[9,1] = '18th October 2002'

# replacing the eleventh row
new_data.iat[10,1] = '15th June 1960'

# replacing the thirty row
new_data.iat[29,1] = '15th June 2000'

# replacing the thirty-one row
new_data.iat[30,1] = '15th June 1960'

# replacing the thirty-two row
new_data.iat[31,1] = '15th July 1910'

# replacing the thirty-three row
new_data.iat[32,1] = '5th August 1900'

# replacing the thirty-four row
new_data.iat[33,1] = '1st May 1962'

# replacing the thirty-five row
new_data.iat[34,1] = '2nd June 1980'

# replacing the thirty-six row
new_data.iat[35,1] = '3rd June 2001'

# replacing the thirty-seven row
new_data.iat[36,1] = '4th Feb. 2000'

# replacing the thirty-eight row
new_data.iat[37,1] = '1st Sep. 1828'

# replacing the thirty-ninth row
new_data.iat[38,1] = '18th October 2002'

# replacing the fourty row
new_data.iat[39,1] = '15th June 1960'

# %%
# Using fillna() method to fill in all the empty row in the DOB column
new_data['DOB'].fillna('1st December 2007', inplace=True)

# %%
# showing the result after using the fillna() method
new_data
# Out:
#     Username                DOB State                           Uniq_id  SKU  \
# 1   cced4433     15th June 2000   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN
# 2   ylwh3213     15th June 1960   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN
# 3   vcqh3224     15th July 1910   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN
# 4   tmse4424    5th August 1900   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN
# 5   awzt1433       1st May 1962   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN
# 6   fcnf1412      2nd June 1980   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN
# 7   owuk2231      3rd June 2001   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN
# 8   ipkl1143      4th Feb. 2000   NaN  16e3ca6b6a2d3f5da9a81df6cfe7e27a  NaN
# 9   rtbj4421      1st Sep. 1828   NaN  209bec04d9f194616358a77d7b41b314  NaN
# 10  rnec1332  18th October 2002   NaN  209bec04d9f194616358a77d7b41b314  NaN
# 11  rgvh4144     15th June 1960   NaN  209bec04d9f194616358a77d7b41b314  NaN
# ...

# %%
# replacing the empty row in the state column using fillna() method

# %%
new_data['State'].fillna('Pensylvania', inplace=True)

# %%
# showing the result after using the fillna() method
new_data
# Out:
#     Username                DOB        State  \
# 1   cced4433     15th June 2000  Pensylvania
# 2   ylwh3213     15th June 1960  Pensylvania
# 3   vcqh3224     15th July 1910  Pensylvania
# 4   tmse4424    5th August 1900  Pensylvania
# 5   awzt1433       1st May 1962  Pensylvania
# 6   fcnf1412      2nd June 1980  Pensylvania
# 7   owuk2231      3rd June 2001  Pensylvania
# 8   ipkl1143      4th Feb. 2000  Pensylvania
# 9   rtbj4421      1st Sep. 1828  Pensylvania
# 10  rnec1332  18th October 2002  Pensylvania
# 11  rgvh4144     15th June 1960  Pensylvania
# 12  crwq1342  1st December 2007  Pensylvania
# 13  bics4343  1st December 2007  Pensylvania
# 14  vcqh3224  1st December 2007  Pensylvania
# 15  qlop1334  1st December 2007  Pensylvania
# 16  jvhg1414  1st December 2007  Pensylvania
# 17  qven4314  1st December 2007  Pensylvania
# 18  hngq1224  1st December 2007  Pensylvania
# 19  lfvh2433  1st December 2007  Pensylvania
# 20  hcot3123  1st December 2007  Pensylvania
# ...

# %%
# replacing the empty rou in the av_score using fillna() method

# %%
new_data['Av_Score'].fillna(4.5, inplace=True)

# %%
# showing the result after using the fillna() method
new_data
# Out:
#     Username                DOB        State  \
# 1   cced4433     15th June 2000  Pensylvania
# 2   ylwh3213     15th June 1960  Pensylvania
# 3   vcqh3224     15th July 1910  Pensylvania
# 4   tmse4424    5th August 1900  Pensylvania
# 5   awzt1433       1st May 1962  Pensylvania
# 6   fcnf1412      2nd June 1980  Pensylvania
# 7   owuk2231      3rd June 2001  Pensylvania
# 8   ipkl1143      4th Feb. 2000  Pensylvania
# 9   rtbj4421      1st Sep. 1828  Pensylvania
# 10  rnec1332  18th October 2002  Pensylvania
# 11  rgvh4144     15th June 1960  Pensylvania
# 12  crwq1342  1st December 2007  Pensylvania
# 13  bics4343  1st December 2007  Pensylvania
# 14  vcqh3224  1st December 2007  Pensylvania
# 15  qlop1334  1st December 2007  Pensylvania
# 16  jvhg1414  1st December 2007  Pensylvania
# 17  qven4314  1st December 2007  Pensylvania
# 18  hngq1224  1st December 2007  Pensylvania
# 19  lfvh2433  1st December 2007  Pensylvania
# 20  hcot3123  1st December 2007  Pensylvania
# ...

# %%
# replacing the empty rou in the name using iat method

# %%
# replacing the first row
new_data.iat[0,5] = 'A bag'

# replacing the second row
new_data.iat[1,5] = 'TV set'

# replacing the third row
new_data.iat[2,5] = 'Bag'

# replacing the fourth row
new_data.iat[3,5] = 'Vaccum'

# replacing the fifth row
new_data.iat[4,5] = 'Car'

# replacing the sixth row
new_data.iat[5,5] = 'Shoe'

# replacing the seventh row
new_data.iat[6,5] = 'Tecno'

# replacing the eight row
new_data.iat[7,5] = 'Samsung'

# replacing the ninth row
new_data.iat[8,5] = 'Techno'

# replacing the tenth row
new_data.iat[9,5] = 'Infinix'

# replacing the eleventh row
new_data.iat[10,5] = 'Infinix'

# replacing the thirty row
new_data.iat[29,5] = 'Tecno'

# replacing the thirty-one row
new_data.iat[30,5] = 'Samsung'

# replacing the thirty-two row
new_data.iat[31,5] = 'Car'

# replacing the thirty-three row
new_data.iat[32,5] = 'Samsung'

# replacing the thirty-four row
new_data.iat[33,5] = 'Tecno'

# replacing the thirty-five row
new_data.iat[34,5] = 'Cloth'

# replacing the thirty-six row
new_data.iat[35,5] = 'Infinix'

# replacing the thirty-seven row
new_data.iat[36,5] = 'Infinix'

# replacing the thirty-eight row
new_data.iat[37,5] = 'Tecno'

# replacing the thirty-ninth row
new_data.iat[38,5] = 'Samsung'

# replacing the fourty row
new_data.iat[39,5] = 'Cloth'

# %%
new_data
# Out:
#     Username                DOB        State  \
# 1   cced4433     15th June 2000  Pensylvania
# 2   ylwh3213     15th June 1960  Pensylvania
# 3   vcqh3224     15th July 1910  Pensylvania
# 4   tmse4424    5th August 1900  Pensylvania
# 5   awzt1433       1st May 1962  Pensylvania
# 6   fcnf1412      2nd June 1980  Pensylvania
# 7   owuk2231      3rd June 2001  Pensylvania
# 8   ipkl1143      4th Feb. 2000  Pensylvania
# 9   rtbj4421      1st Sep. 1828  Pensylvania
# 10  rnec1332  18th October 2002  Pensylvania
# 11  rgvh4144     15th June 1960  Pensylvania
# 12  crwq1342  1st December 2007  Pensylvania
# 13  bics4343  1st December 2007  Pensylvania
# 14  vcqh3224  1st December 2007  Pensylvania
# 15  qlop1334  1st December 2007  Pensylvania
# 16  jvhg1414  1st December 2007  Pensylvania
# 17  qven4314  1st December 2007  Pensylvania
# 18  hngq1224  1st December 2007  Pensylvania
# 19  lfvh2433  1st December 2007  Pensylvania
# 20  hcot3123  1st December 2007  Pensylvania
# ...

# %%
# replacing the empty row in the name column using fillna() method

# %%
new_data['Name'].fillna('bus', inplace=True)

# %%
# showing the result after using the fillna() method
new_data
# Out:
#     Username                DOB        State  \
# 1   cced4433     15th June 2000  Pensylvania
# 2   ylwh3213     15th June 1960  Pensylvania
# 3   vcqh3224     15th July 1910  Pensylvania
# 4   tmse4424    5th August 1900  Pensylvania
# 5   awzt1433       1st May 1962  Pensylvania
# 6   fcnf1412      2nd June 1980  Pensylvania
# 7   owuk2231      3rd June 2001  Pensylvania
# 8   ipkl1143      4th Feb. 2000  Pensylvania
# 9   rtbj4421      1st Sep. 1828  Pensylvania
# 10  rnec1332  18th October 2002  Pensylvania
# 11  rgvh4144     15th June 1960  Pensylvania
# 12  crwq1342  1st December 2007  Pensylvania
# 13  bics4343  1st December 2007  Pensylvania
# 14  vcqh3224  1st December 2007  Pensylvania
# 15  qlop1334  1st December 2007  Pensylvania
# 16  jvhg1414  1st December 2007  Pensylvania
# 17  qven4314  1st December 2007  Pensylvania
# 18  hngq1224  1st December 2007  Pensylvania
# 19  lfvh2433  1st December 2007  Pensylvania
# 20  hcot3123  1st December 2007  Pensylvania
# ...

# %%
# replacing the empty row in the price column using fillna() method

# %%
new_data['Price'].fillna(50000, inplace=True)

# %%
# showing the result after using the fillna() method
new_data
# Out:
#     Username                DOB        State  \
# 1   cced4433     15th June 2000  Pensylvania
# 2   ylwh3213     15th June 1960  Pensylvania
# 3   vcqh3224     15th July 1910  Pensylvania
# 4   tmse4424    5th August 1900  Pensylvania
# 5   awzt1433       1st May 1962  Pensylvania
# 6   fcnf1412      2nd June 1980  Pensylvania
# 7   owuk2231      3rd June 2001  Pensylvania
# 8   ipkl1143      4th Feb. 2000  Pensylvania
# 9   rtbj4421      1st Sep. 1828  Pensylvania
# 10  rnec1332  18th October 2002  Pensylvania
# 11  rgvh4144     15th June 1960  Pensylvania
# 12  crwq1342  1st December 2007  Pensylvania
# 13  bics4343  1st December 2007  Pensylvania
# 14  vcqh3224  1st December 2007  Pensylvania
# 15  qlop1334  1st December 2007  Pensylvania
# 16  jvhg1414  1st December 2007  Pensylvania
# 17  qven4314  1st December 2007  Pensylvania
# 18  hngq1224  1st December 2007  Pensylvania
# 19  lfvh2433  1st December 2007  Pensylvania
# 20  hcot3123  1st December 2007  Pensylvania
# ...

# %%
# replacing the empty row in the SKU column using fillna() method

# %%
new_data['SKU'].fillna('dhjg12980', inplace=True)

# %%
# showing the result after using the fillna() method
new_data
# Out:
#     Username                DOB        State  \
# 1   cced4433     15th June 2000  Pensylvania
# 2   ylwh3213     15th June 1960  Pensylvania
# 3   vcqh3224     15th July 1910  Pensylvania
# 4   tmse4424    5th August 1900  Pensylvania
# 5   awzt1433       1st May 1962  Pensylvania
# 6   fcnf1412      2nd June 1980  Pensylvania
# 7   owuk2231      3rd June 2001  Pensylvania
# 8   ipkl1143      4th Feb. 2000  Pensylvania
# 9   rtbj4421      1st Sep. 1828  Pensylvania
# 10  rnec1332  18th October 2002  Pensylvania
# 11  rgvh4144     15th June 1960  Pensylvania
# 12  crwq1342  1st December 2007  Pensylvania
# 13  bics4343  1st December 2007  Pensylvania
# 14  vcqh3224  1st December 2007  Pensylvania
# 15  qlop1334  1st December 2007  Pensylvania
# 16  jvhg1414  1st December 2007  Pensylvania
# 17  qven4314  1st December 2007  Pensylvania
# 18  hngq1224  1st December 2007  Pensylvania
# 19  lfvh2433  1st December 2007  Pensylvania
# 20  hcot3123  1st December 2007  Pensylvania
# ...

# %%
# replacing the empty row in the description column using fillna() method

# %%
new_data['Description'].fillna('Good product', inplace=True)

# %%
# showing the result after using the fillna() method
new_data
# Out:
#     Username                DOB        State  \
# 1   cced4433     15th June 2000  Pensylvania
# 2   ylwh3213     15th June 1960  Pensylvania
# 3   vcqh3224     15th July 1910  Pensylvania
# 4   tmse4424    5th August 1900  Pensylvania
# 5   awzt1433       1st May 1962  Pensylvania
# 6   fcnf1412      2nd June 1980  Pensylvania
# 7   owuk2231      3rd June 2001  Pensylvania
# 8   ipkl1143      4th Feb. 2000  Pensylvania
# 9   rtbj4421      1st Sep. 1828  Pensylvania
# 10  rnec1332  18th October 2002  Pensylvania
# 11  rgvh4144     15th June 1960  Pensylvania
# 12  crwq1342  1st December 2007  Pensylvania
# 13  bics4343  1st December 2007  Pensylvania
# 14  vcqh3224  1st December 2007  Pensylvania
# 15  qlop1334  1st December 2007  Pensylvania
# 16  jvhg1414  1st December 2007  Pensylvania
# 17  qven4314  1st December 2007  Pensylvania
# 18  hngq1224  1st December 2007  Pensylvania
# 19  lfvh2433  1st December 2007  Pensylvania
# 20  hcot3123  1st December 2007  Pensylvania
# ...

# %%
# checking for any empty or missing field

# %%
new_data.isnull().sum()
# Out:
# Username       0
# DOB            0
# State          0
# Uniq_id        0
# SKU            0
# Name           0
# Description    0
# Price          0
# Av_Score       0
# Score          0
# Review         0
# dtype: int64

# %%
# Visualizing the data

# %%
# using matplotlib for the visualization 
new_data_visuals = new_data['Name'].value_counts().hist(bins=25)
new_data_visuals.set_title('New data graph', fontsize=25)
new_data_visuals.set_xlabel('Name', fontsize=20)
new_data_visuals.set_ylabel('No. Of Occurance',fontsize=20)
# Out:
# Text(0, 0.5, 'No. Of Occurance')

# %%
# this is an histogram representation of our new data

# %% [markdown]
# # To demonstrate that our program can read through a Json file

# %%
# using the json library to read through a json file
import json # using json libary

# %%
# writing a function that enable us read through teh json file
with open('jcpenney_reviewers.json') as file:
    data = json.load(file)

# %%
# displaying the json result
data
# Out:
# [{'Username': 'bkpn1412',
#   'DOB': '31.07.1983',
#   'State': 'Oregon',
#   'Reviewed': ['cea76118f6a9110a893de2b7654319c0']},
#  {'Username': 'gqjs4414',
#   'DOB': '27.07.1998',
#   'State': 'Massachusetts',
#   'Reviewed': ['fa04fe6c0dd5189f54fe600838da43d3']},
#  {'Username': 'eehe1434',
#   'DOB': '08.08.1950',
#   'State': 'Idaho',
#   'Reviewed': []},
#  {'Username': 'hkxj1334',
#   'DOB': '03.08.1969',
#   'State': 'Florida',
#   'Reviewed': ['f129b1803f447c2b1ce43508fb822810',
#    '3b0c9bc0be65a3461893488314236116']},
#  {'Username': 'jjbd1412',
#   'DOB': '26.07.2001',
#   'State': 'Georgia',
#   'Reviewed': []},
#  {'Username': 'rriz2231',
#   'DOB': '08.08.1951',
#   'State': 'Montana',
#   'Reviewed': ['b3b3343d6ee7662ea7decbce740196ea']},
#  {'Username': 'dvmv4241',
#   'DOB': '02.08.1975',
#   'State': 'Pennsylvania',
#   'Reviewed': ['68f724f2be6674413da9d3a39b951327',
#    '33a8fe5231cc61a0ff266db82323dbcb']},
#  {'Username': 'ibtk1124',
#   'DOB': '31.07.1983',
# ...

# %% [markdown]
# # Doing something interesting with the reviews.csv file

# %% [markdown]
# # Using the data in the file we are going to perform a reviewer sentiment analysis that will enable the company to get an idea of how customers perceive the products. Which will help them make improvements, tailor marketing strategies, and understand what aspects customers like or dislike about their offerings.

# %%
# To achive this we need to read through the file first

# %%
import pandas as pd
from textblob import TextBlob # which will help us carry out this analysis

# %%
# we now load the file by reading through it

# %%
# reading and loading the file
review_analysis = pd.read_csv('reviews.csv.csv')

# %%
# Function to perform sentiment analysis on reviewer comments
def sentiment_analysis(text):
    blob = TextBlob(text)
    sentiment_score = blob.sentiment.polarity
    return sentiment_score

# Perform sentiment analysis on reviewer comments
review_analysis['Sentiment_Score'] = review_analysis['Review'].apply(sentiment_analysis)
review_analysis[['Uniq_id', 'Review', 'Sentiment_Score']]
# Out:
#                                 Uniq_id  \
# 0      b6c0b6bea69c722939585baeac73c13d
# 1      b6c0b6bea69c722939585baeac73c13d
# 2      b6c0b6bea69c722939585baeac73c13d
# 3      b6c0b6bea69c722939585baeac73c13d
# 4      b6c0b6bea69c722939585baeac73c13d
# ...                                 ...
# 39058  2cc49292b44cc12fe22206440d3e7472
# 39059  2cc49292b44cc12fe22206440d3e7472
# 39060  2cc49292b44cc12fe22206440d3e7472
# 39061  2cc49292b44cc12fe22206440d3e7472
# 39062  2cc49292b44cc12fe22206440d3e7472
#
#                                                   Review  Sentiment_Score
# 0      You never have to worry about the fit...Alfred...         0.575000
# 1      Good quality fabric. Perfect fit. Washed very ...         0.575000
# 2      I do not normally wear pants or capris that ha...         0.281000
# 3      I love these capris! They fit true to size and...         0.455000
# 4      This product is very comfortable and the fabri...         0.360000
# ...

# %%
# getting the first seven rows from our review_analysis
review_analysis.head(7)
# Out:
#                             Uniq_id  Username  Score  \
# 0  b6c0b6bea69c722939585baeac73c13d  fsdv4141      2
# 1  b6c0b6bea69c722939585baeac73c13d  krpz1113      1
# 2  b6c0b6bea69c722939585baeac73c13d  mbmg3241      2
# 3  b6c0b6bea69c722939585baeac73c13d  zeqg1222      0
# 4  b6c0b6bea69c722939585baeac73c13d  nvfn3212      3
# 5  b6c0b6bea69c722939585baeac73c13d  aajh3423      2
# 6  b6c0b6bea69c722939585baeac73c13d  usvp2142      1
#
#                                               Review  Sentiment_Score
# 0  You never have to worry about the fit...Alfred...           0.5750
# 1  Good quality fabric. Perfect fit. Washed very ...           0.5750
# 2  I do not normally wear pants or capris that ha...           0.2810
# 3  I love these capris! They fit true to size and...           0.4550
# 4  This product is very comfortable and the fabri...           0.3600
# 5  I did not like the fabric. It is 100% polyeste...           0.0000
# ...
